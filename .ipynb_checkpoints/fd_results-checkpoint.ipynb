# %%
import time, re, csv
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait # available since 2.4.0
from selenium.webdriver.support import expected_conditions as EC # available since 2.26.0
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
from datetime import datetime
import logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')
driver = webdriver.Chrome('C:\Anaconda3\selenium\webdriver\chrome\chromedriver')

# %%
driver.get("https://www.fanduel.com/p/login")
#implement wait it is mandatory in this case
WebDriverWait(driver,1000).until(EC.presence_of_all_elements_located((By.XPATH,"(//footer)")))

driver.find_element_by_name("email").send_keys("pmracek@gmail.com")
driver.find_element_by_name("password").send_keys("fcvb25WERL")
driver.find_element_by_name("login").click()
# Out:
# <!DOCTYPE html><!--[if lt IE 7]><html class="lt-ie10 lt-ie9 lt-ie8 lt-ie7" lang="en"> <![endif]--><!--[if IE 7]><html class="lt-ie10 lt-ie9 lt-ie8" lang="en"> <![endif]--><!--[if IE 8]><html class="lt-ie10 lt-ie9" lang="en"> <![endif]--><!--[if IE 9]><html class="lt-ie10" lang="en"> <![endif]--><!--[if gt IE 9]><!--><html xmlns="http://www.w3.org/1999/xhtml" lang="en" class="  fontloader fontloader__proxima--loaded"><!--<![endif]--><head><style type="text/css">@charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\:form{display:block;}</style>
#     <meta charset="utf-8" />
#     <meta name="google-site-verification" content="7bfPVLres-pmKiWuUbGn657RuKrQAPME6CG5Vkr60LI" />
#     <meta property="twitter:account_id" content="4503599629457078" />
#
#         <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#
#
# ...

# %%
contest_urls = ['https://www.fanduel.com/entry/ECVALPVHI'
,'https://www.fanduel.com/entry/DGWZTVJMV'
,'https://www.fanduel.com/entry/FAVHDAVLG'
,'https://www.fanduel.com/entry/AQXVNMZUE'
,'https://www.fanduel.com/entry/BZDPGIMSY'
,'https://www.fanduel.com/entry/ANSIOZNSF'
,'https://www.fanduel.com/entry/ESUPTNGIQ'
,'https://www.fanduel.com/entry/ALAUWEIWU'
,'https://www.fanduel.com/entry/CATQLQXCI'
,'https://www.fanduel.com/entry/AOUMHJAFE'
,'https://www.fanduel.com/entry/BKEPTBNGP'
,'https://www.fanduel.com/entry/DMSTDNLYA'
]

driver.get(contest_urls[0])
soup = BeautifulSoup(driver.page_source)
entries = soup.find_all('li', attrs={'class':'live-leaderboard-entry'})
for entry in entries:
    rank = entry.find('span', attrs={'class':'rank'}).text
    username = entry.find('span', attrs={'class':'username'}).text
    score = entry.find('camel-number')['value']
    winnings = entry.find('span', attrs={'class':'user-winnings'}).text.strip()

# %%
print(entry.find('camel-number')['value'])


print(entry.contents)
# Out:
# 105.7
# ['\n', <div class="live-leaderboard-entry-details">
# <div class="user-info">
# <span class="rank">3rd</span>
# <span class="avatar avatar-inline" style="background-image: url('/images/member_defaultpic.gif');"></span>
# <span class="username">cmarlatt9</span>
# </div>
# <span class="user-winnings">
# 							$9.50
# 							<span class="user-winnings-label">Won</span>
# </span>
# <div class="user-ppr-score">
# <div class="periods-remaining" remaining="entry.roster.ppr" roster-length="detail.contest.rosterPositions.length" sport="detail.contest.fixtureList.sport">
# <div class="periods-remaining-value">
# <div class="pr-figure">
# <span class="pr-value"><b>0</b></span>
# <span class="periods-remaining-progress">
# <span class="remaining" ng-attr-style="width: {{ (pr.remaining / (pr.sportPeriods[pr.sport].value * pr.rosterLength) * 100).toFixed(2) }}%;" style="width: 0.00%;"></span>
# </span>
# </div>
# ...
