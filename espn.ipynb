# %%
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait # available since 2.4.0
from selenium.webdriver.support import expected_conditions as EC # available since 2.26.0
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

def getdriver():
	driver = webdriver.Chrome(r'C:\Users\PM186016\Dropbox\Python\selenium\webdriver\chrome\chromedriver')

	driver.get("http://games.espn.go.com/ffl/signin")
	#implement wait it is mandatory in this case
	#WebDriverWait(driver,1000).until(EC.presence_of_all_elements_located((By.XPATH,"(//iframe)")))
	frms = driver.find_elements_by_tag_name("iframe")

	for i in range(len(frms)):
		driver.switch_to_default_content()
		#time.sleep(1)
		try:
			driver.switch_to_frame(frms[i])
			#time.sleep(1)
			driver.find_element_by_xpath('(//input[@type="email"])').send_keys("pmracek@gmail.com")
			driver.find_element_by_xpath('(//input[@type="password"])').send_keys("aissaj")
			driver.find_element_by_xpath("//button").click()
			break
		except:
			pass
	return driver

def class_not_spacer(tag):
	return not tag.has_attr('class') or (tag.has_attr('class') and not re.match("sectionLeadingSpacer", ' '.join(tag['class'])))  # have to use the ' '.join() syntax because tag['class'] is actually a list

# %%
driver = webdriver.Chrome(r'C:\Users\PM186016\Dropbox\Python\selenium\webdriver\chrome\chromedriver')

# %%
getdriver()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-667ff97d0574> in <module>()
#       1 getdriver()
# ----> 2 print(driver.all_cookies)
#
# AttributeError: 'WebDriver' object has no attribute 'all_cookies'

# %%
import requests
from bs4 import BeautifulSoup

s = requests.Session()

url = 'http://games.espn.go.com/ffl/signin'
payload = {'username':'pmracek'
,'password':'aissaj'
,'failedAttempts':'2'
,'SUBMIT':'1'
,'failedLocation':'http://games.espn.go.com/ffl/signin?redir=http%3A%2F%2Fgames.espn.go.com%2Fffl%2Fwaiverreport%3Fdate%3D20130928%26leagueId%3D111414&e=1'
,'aff_code':'espn_fantgames'
,'appRedirect':'http://games.espn.go.com/ffl/waiverreport?date=20130928&leagueId=111414'
,'cookieDomain':'.go.com'
,'multipleDomains':'true'}	
r = s.get(url)

soup = BeautifulSoup(r.text, "lxml")

# %%
print(soup.text)
# Out:
# Log In - Free Fantasy Football -  ESPN
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		/* omniture ad tracking v0.1 24Jun08 */
# 		var anAds;
# 		anAds="";
# 		function anPassAds(str) {
# 			anAds=anAds?anAds+",ads;"+str+";;;event38=1":"ads;"+str+";;;event38=1";
# 		}
#
# ...

# %%
for i in range(len(frms)):
    driver.switch_to_default_content()
    #time.sleep(1)
    try:
        driver.switch_to_frame(frms[i])
        #time.sleep(1)
        driver.find_element_by_xpath('(//input[@type="email"])').send_keys("pmracek@gmail.com")
        driver.find_element_by_xpath('(//input[@type="password"])').send_keys("aissaj")
        driver.find_element_by_xpath("//button").click()
        break
    except:
        pass
